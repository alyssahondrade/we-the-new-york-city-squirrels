# %%
# Import dependencies
import pandas as pd
from pathlib import Path
import re

# %% [markdown]
# # Import Data

# %%
# Base datasets
squirrel_2020 = Path("Resources/squirrel_data_2020.csv")
squirrel_2018 = Path("Resources/squirrel_data_2018.csv")

# Additional dataset from 2020
parks_2020 = Path("Resources/park_data_2020.csv")

# %% [markdown]
# ---
# ### Hello, this is a test

# %% [markdown]
# ##### Second test cell
# ---

# %% [markdown]
# # 2020 Dataset - Squirrels

# %% [markdown]
# ## This is the test code from Alyssa

# %%
# Create dataframe from CSV
s2020_df = pd.read_csv(squirrel_2020, encoding="unicode_escape")

# Display DataFrame and its shape
print(f"2020 Squirrel Dataset: {s2020_df.shape}")
s2020_df.head()
# Out:
# 2020 Squirrel Dataset: (433, 16)
#          Area Name Area ID        Park Name  Park ID Squirrel ID  \
# 0  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-01
# 1  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-02
# 2  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-03
# 3  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-04
# 4  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-05
#
#   Primary Fur Color Highlights in Fur Color Color Notes      Location  \
# 0              Gray                   White         NaN  Ground Plane
# 1              Gray                   White         NaN  Ground Plane
# 2              Gray                   White         NaN  Ground Plane
# 3              Gray                   White         NaN  Ground Plane
# 4              Gray                Cinnamon         NaN  Ground Plane
#
#   Above Ground (Height in Feet) Specific Location                 Activities  \
# 0                           NaN               NaN                   Foraging
# 1                           NaN               NaN                   Foraging
# 2                           NaN               NaN  Eating, Digging something
# 3                           NaN               NaN                    Running
# 4                           NaN               NaN            Running, Eating
#
#   Interactions with Humans Other Notes or Observations  \
# 0              Indifferent                         NaN
# 1              Indifferent                Looks skinny
# 2              Indifferent                         NaN
# 3              Indifferent                         NaN
# 4              Indifferent               She left food
#
#    Squirrel Latitude (DD.DDDDDD)  Squirrel Longitude (-DD.DDDDDD)
# 0                      40.859410                       -73.933936
# 1                      40.859436                       -73.933937
# 2                      40.859416                       -73.933894
# 3                      40.859418                       -73.933895
# 4                      40.859493                       -73.933590

# %%
# Identify the non-null count and data types
s2020_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433 entries, 0 to 432
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Area Name                        433 non-null    object
#  1   Area ID                          433 non-null    object
#  2   Park Name                        433 non-null    object
#  3   Park ID                          433 non-null    int64
#  4   Squirrel ID                      433 non-null    object
#  5   Primary Fur Color                432 non-null    object
#  6   Highlights in Fur Color          339 non-null    object
#  7   Color Notes                      10 non-null     object
#  8   Location                         399 non-null    object
#  9   Above Ground (Height in Feet)    112 non-null    object
#  10  Specific Location                89 non-null     object
#  11  Activities                       378 non-null    object
#  12  Interactions with Humans         342 non-null    object
#  13  Other Notes or Observations      167 non-null    object
#  14  Squirrel Latitude (DD.DDDDDD)    341 non-null    float64
#  15  Squirrel Longitude (-DD.DDDDDD)  341 non-null    float64
# dtypes: float64(2), int64(1), object(13)
# memory usage: 54.3+ KB

# %%
# Drop null values for minimum requirement columns
dropna_columns = [
    "Primary Fur Color",
    "Highlights in Fur Color",
    "Activities",
    "Interactions with Humans",
    "Squirrel Latitude (DD.DDDDDD)",
    "Squirrel Longitude (-DD.DDDDDD)"
]

s2020_nonull = s2020_df.dropna(subset=dropna_columns, how="any")

# Display DataFrame and its shape
print(f"{s2020_nonull.shape}")
s2020_nonull.head()
# Out:
# (192, 16)
#          Area Name Area ID        Park Name  Park ID Squirrel ID  \
# 0  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-01
# 1  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-02
# 2  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-03
# 3  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-04
# 4  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-05
#
#   Primary Fur Color Highlights in Fur Color Color Notes      Location  \
# 0              Gray                   White         NaN  Ground Plane
# 1              Gray                   White         NaN  Ground Plane
# 2              Gray                   White         NaN  Ground Plane
# 3              Gray                   White         NaN  Ground Plane
# 4              Gray                Cinnamon         NaN  Ground Plane
#
#   Above Ground (Height in Feet) Specific Location                 Activities  \
# 0                           NaN               NaN                   Foraging
# 1                           NaN               NaN                   Foraging
# 2                           NaN               NaN  Eating, Digging something
# 3                           NaN               NaN                    Running
# 4                           NaN               NaN            Running, Eating
#
#   Interactions with Humans Other Notes or Observations  \
# 0              Indifferent                         NaN
# 1              Indifferent                Looks skinny
# 2              Indifferent                         NaN
# 3              Indifferent                         NaN
# 4              Indifferent               She left food
#
#    Squirrel Latitude (DD.DDDDDD)  Squirrel Longitude (-DD.DDDDDD)
# 0                      40.859410                       -73.933936
# 1                      40.859436                       -73.933937
# 2                      40.859416                       -73.933894
# 3                      40.859418                       -73.933895
# 4                      40.859493                       -73.933590

# %%
# Identify the non-null count and data types
s2020_nonull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 192 entries, 0 to 432
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Area Name                        192 non-null    object
#  1   Area ID                          192 non-null    object
#  2   Park Name                        192 non-null    object
#  3   Park ID                          192 non-null    int64
#  4   Squirrel ID                      192 non-null    object
#  5   Primary Fur Color                192 non-null    object
#  6   Highlights in Fur Color          192 non-null    object
#  7   Color Notes                      5 non-null      object
#  8   Location                         192 non-null    object
#  9   Above Ground (Height in Feet)    58 non-null     object
#  10  Specific Location                28 non-null     object
#  11  Activities                       192 non-null    object
#  12  Interactions with Humans         192 non-null    object
#  13  Other Notes or Observations      96 non-null     object
#  14  Squirrel Latitude (DD.DDDDDD)    192 non-null    float64
#  15  Squirrel Longitude (-DD.DDDDDD)  192 non-null    float64
# dtypes: float64(2), int64(1), object(13)
# memory usage: 25.5+ KB

# %% [markdown]
# ## Columns Cleaning
# - Remove columns:
#     - 'Color Notes', irrelevant and too few data points.
#     - 'Location', 'Above Ground (...)', and 'Specific Location', irrelevant and would take too much resources to clean the data.
# - Rename columns: use underscores, all lower case.

# %%
# Check the 'Location' column
s2020_nonull['Location'].value_counts()
# Out:
# Ground Plane                       113
# Above Ground                        48
# Above Ground, Specific Location     20
# Ground Plane, Above Ground           5
# Ground Plane, Specific Location      5
# Specific Location                    1
# Name: Location, dtype: int64

# %%
# Drop columns
drop_columns = ["Color Notes", "Location", "Above Ground (Height in Feet)", "Specific Location"]

reduced_2020 = s2020_nonull.drop(columns=drop_columns)
reduced_2020.head()
# Out:
#          Area Name Area ID        Park Name  Park ID Squirrel ID  \
# 0  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-01
# 1  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-02
# 2  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-03
# 3  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-04
# 4  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-05
#
#   Primary Fur Color Highlights in Fur Color                 Activities  \
# 0              Gray                   White                   Foraging
# 1              Gray                   White                   Foraging
# 2              Gray                   White  Eating, Digging something
# 3              Gray                   White                    Running
# 4              Gray                Cinnamon            Running, Eating
#
#   Interactions with Humans Other Notes or Observations  \
# 0              Indifferent                         NaN
# 1              Indifferent                Looks skinny
# 2              Indifferent                         NaN
# 3              Indifferent                         NaN
# 4              Indifferent               She left food
#
#    Squirrel Latitude (DD.DDDDDD)  Squirrel Longitude (-DD.DDDDDD)
# 0                      40.859410                       -73.933936
# 1                      40.859436                       -73.933937
# 2                      40.859416                       -73.933894
# 3                      40.859418                       -73.933895
# 4                      40.859493                       -73.933590

# %%
# Rename the columns
cols_df = pd.DataFrame(s2020_nonull.columns, columns=["name"])

# Define the regex pattern
pattern = '\((.*?)\)' # \( and \) to escape brackets, *.? matches any character (non-newline) zero or more times

new_columns = []
for row in cols_df["name"]:
    stripped_row = re.findall(pattern, row)

    # Remove the brackets and content
    if len(stripped_row) > 0:
        remove_substring = f' ({stripped_row[0].strip("[]")})'
        row = row.strip(remove_substring)

    # Use underscore and cast to lowercase
    new_columns.append(row.replace(" ", "_").lower())

# Update the columns
s2020_nonull.columns = new_columns

s2020_nonull.head()
# Out:
#          area_name area_id        park_name  park_id squirrel_id  \
# 0  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-01
# 1  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-02
# 2  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-03
# 3  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-04
# 4  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-05
#
#   primary_fur_color highlights_in_fur_color color_notes      location  \
# 0              Gray                   White         NaN  Ground Plane
# 1              Gray                   White         NaN  Ground Plane
# 2              Gray                   White         NaN  Ground Plane
# 3              Gray                   White         NaN  Ground Plane
# 4              Gray                Cinnamon         NaN  Ground Plane
#
#   above_ground specific_location                 activities  \
# 0          NaN               NaN                   Foraging
# 1          NaN               NaN                   Foraging
# 2          NaN               NaN  Eating, Digging something
# 3          NaN               NaN                    Running
# 4          NaN               NaN            Running, Eating
#
#   interactions_with_humans other_notes_or_observations  squirrel_latitude  \
# 0              Indifferent                         NaN          40.859410
# 1              Indifferent                Looks skinny          40.859436
# 2              Indifferent                         NaN          40.859416
# 3              Indifferent                         NaN          40.859418
# 4              Indifferent               She left food          40.859493
#
#    squirrel_longitude
# 0          -73.933936
# 1          -73.933937
# 2          -73.933894
# 3          -73.933895
# 4          -73.933590

# %% [markdown]
# ## Clean 'activities' column

# %%
# Create a DataFrame of the 'activities' column for cleaning
activities_df = s2020_nonull[['squirrel_id', 'activities']].copy()
activities_df
# Out:
#     squirrel_id                  activities
# 0       A-01-01                    Foraging
# 1       A-01-02                    Foraging
# 2       A-01-03   Eating, Digging something
# 3       A-01-04                     Running
# 4       A-01-05             Running, Eating
# ..          ...                         ...
# 428     D-22-40                    Foraging
# 429     D-22-41           Running, Foraging
# 430     D-22-42                    Climbing
# 431     D-22-43  Running, Chasing, Climbing
# 432     D-22-44                    Foraging
#
# [192 rows x 2 columns]

# %%
activities = []

# Split the activities column
for sighting in s2020_nonull['activities']:
    activities.append(sighting.split(", "))

# Flatten the list
all_activities = [value.lower() for row in activities for value in row]

# Get the unique activities
unique_activities = set(all_activities)
unique_activities

# 2018 equivalent activities
# parsed_list = ["running", "chasing", "climbing", "eating", "foraging"]

activities_df = pd.DataFrame(all_activities)
activities_df.value_counts()
# Out:
# foraging                         71
# climbing                         51
# eating                           45
# running                          37
# chasing                          20
# shouting                         10
# defending tree                    6
# sitting                           6
# digging                           2
# burying                           2
# battery                           1
# sitting in short tree             1
# sticking out of a tree            1
# sleeping                          1
# sleeping (dead?)                  1
# very carefully watching a cat     1
# vocalization at us                1
# self-cleaning                     1
# hanging out                       1
# posing                            1
# nesting/gathering leaves          1
# jumping                           1
# hanging                           1
# eating (or pretending to eat)     1
# eating (nuts)                     1
# eating (bread crumbs)             1
# digging something                 1
# chilling                          1
# watching #2                       1
# dtype: int64

# %%
activities_list_df = pd.Series(activities)
activities_list_df
# Out:
# 0                        [Foraging]
# 1                        [Foraging]
# 2       [Eating, Digging something]
# 3                         [Running]
# 4                 [Running, Eating]
#                    ...
# 187                      [Foraging]
# 188             [Running, Foraging]
# 189                      [Climbing]
# 190    [Running, Chasing, Climbing]
# 191                      [Foraging]
# Length: 192, dtype: object

# %%
# Combine all the "eating"
# s2020_nonull[s2020_nonull['activities'].str.startswith("Eating (")]['activities']
s2020_nonull[s2020_nonull['squirrel_id'] == "C-18-01"]
# Out:
#            area_name area_id      park_name  park_id squirrel_id  \
# 330  LOWER MANHATTAN       C  Teardrop Park       18     C-18-01
#
#     primary_fur_color highlights_in_fur_color color_notes      location  \
# 330              Gray                Cinnamon         NaN  Ground Plane
#
#     above_ground specific_location                              activities  \
# 330          NaN               NaN  Running, Eating (or pretending to eat)
#
#     interactions_with_humans  \
# 330                Runs From
#
#                            other_notes_or_observations  squirrel_latitude  \
# 330  Ran up tree and down tree, tail vibration ÛÓ ...          40.716335
#
#      squirrel_longitude
# 330          -74.015612

# %%
s2020_nonull[s2020_nonull['activities'].str.endswith("Eating (or pretending to eat)")]
# Out:
#            area_name area_id      park_name  park_id squirrel_id  \
# 330  LOWER MANHATTAN       C  Teardrop Park       18     C-18-01
#
#     primary_fur_color highlights_in_fur_color color_notes      location  \
# 330              Gray                Cinnamon         NaN  Ground Plane
#
#     above_ground specific_location                              activities  \
# 330          NaN               NaN  Running, Eating (or pretending to eat)
#
#     interactions_with_humans  \
# 330                Runs From
#
#                            other_notes_or_observations  squirrel_latitude  \
# 330  Ran up tree and down tree, tail vibration ÛÓ ...          40.716335
#
#      squirrel_longitude
# 330          -74.015612

# %% [markdown]
# # 2018 Dataset - Squirrels

# %%
# Create dataframe from CSV
s2018_df = pd.read_csv(squirrel_2018)

# Display DataFrame and its shape
print(f"2018 Dataset: {s2018_df.shape}")
s2018_df.head()
# Out:
# 2018 Dataset: (3023, 31)
#            X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.968857  40.783783     21B-AM-1019-04     21B    AM  10192018
# 2 -73.974281  40.775534     11B-PM-1014-08     11B    PM  10142018
# 3 -73.959641  40.790313     32E-PM-1017-14     32E    PM  10172018
# 4 -73.970268  40.776213     13E-AM-1017-05     13E    AM  10172018
#
#    Hectare Squirrel Number    Age Primary Fur Color Highlight Fur Color  ...  \
# 0                        3    NaN               NaN                 NaN  ...
# 1                        4    NaN               NaN                 NaN  ...
# 2                        8    NaN              Gray                 NaN  ...
# 3                       14  Adult              Gray                 NaN  ...
# 4                        5  Adult              Gray            Cinnamon  ...
#
#     Kuks  Quaas  Moans Tail flags Tail twitches  Approaches  Indifferent  \
# 0  False  False  False      False         False       False        False
# 1  False  False  False      False         False       False        False
# 2  False  False  False      False         False       False        False
# 3  False  False  False      False         False       False        False
# 4  False  False  False      False         False       False        False
#
#    Runs from  Other Interactions                                    Lat/Long
# 0      False                 NaN  POINT (-73.9561344937861 40.7940823884086)
# 1      False                 NaN  POINT (-73.9688574691102 40.7837825208444)
# 2      False                 NaN  POINT (-73.97428114848522 40.775533619083)
# 3       True                 NaN  POINT (-73.9596413903948 40.7903128889029)
# 4      False                 NaN  POINT (-73.9702676472613 40.7762126854894)
#
# [5 rows x 31 columns]

# %%
# Identify the non-null count and data types
s2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3023 entries, 0 to 3022
# Data columns (total 31 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   X                                           3023 non-null   float64
#  1   Y                                           3023 non-null   float64
#  2   Unique Squirrel ID                          3023 non-null   object
#  3   Hectare                                     3023 non-null   object
#  4   Shift                                       3023 non-null   object
#  5   Date                                        3023 non-null   int64
#  6   Hectare Squirrel Number                     3023 non-null   int64
#  7   Age                                         2902 non-null   object
#  8   Primary Fur Color                           2968 non-null   object
#  9   Highlight Fur Color                         1937 non-null   object
#  10  Combination of Primary and Highlight Color  3023 non-null   object
#  11  Color notes                                 182 non-null    object
#  12  Location                                    2959 non-null   object
#  13  Above Ground Sighter Measurement            2909 non-null   object
#  14  Specific Location                           476 non-null    object
#  15  Running                                     3023 non-null   bool
#  16  Chasing                                     3023 non-null   bool
#  17  Climbing                                    3023 non-null   bool
#  18  Eating                                      3023 non-null   bool
#  19  Foraging                                    3023 non-null   bool
#  20  Other Activities                            437 non-null    object
#  21  Kuks                                        3023 non-null   bool
#  22  Quaas                                       3023 non-null   bool
#  23  Moans                                       3023 non-null   bool
#  24  Tail flags                                  3023 non-null   bool
#  25  Tail twitches                               3023 non-null   bool
#  26  Approaches                                  3023 non-null   bool
#  27  Indifferent                                 3023 non-null   bool
#  28  Runs from                                   3023 non-null   bool
#  29  Other Interactions                          240 non-null    object
#  30  Lat/Long                                    3023 non-null   object
# dtypes: bool(13), float64(2), int64(2), object(14)
# memory usage: 463.6+ KB

# %%
# 2018 Dataset

# Drop null values for minimum requirement columns
s2018_nonull = s2018_df.dropna(
    subset=["Primary Fur Color", "Highlight Fur Color", "Running", "Chasing", "Climbing", "Eating", "Foraging", "Approaches", "Indifferent", "Runs from", "X", "Y"],
    how="any")

# NOTE: If you add "Other Interactions", dataset is reduced to 170 rows
# Number of unique values for "Other Notes or Observations"
print(f'Unique "other interactions": {s2018_nonull["Other Interactions"].nunique()}') # 152 unique interactions

# Display DataFrame and its shape
print(f"{s2018_nonull.shape}")
s2018_nonull.head()
# Out:
# Unique "other interactions": 152
# (1937, 31)
#             X          Y Unique Squirrel ID Hectare Shift      Date  \
# 4  -73.970268  40.776213     13E-AM-1017-05     13E    AM  10172018
# 5  -73.968361  40.772591     11H-AM-1010-03     11H    AM  10102018
# 9  -73.972250  40.774288     11D-AM-1010-03     11D    AM  10102018
# 10 -73.969506  40.782351     20B-PM-1013-05     20B    PM  10132018
# 12 -73.953217  40.791967     36I-PM-1007-01     36I    PM  10072018
#
#     Hectare Squirrel Number    Age Primary Fur Color Highlight Fur Color  ...  \
# 4                         5  Adult              Gray            Cinnamon  ...
# 5                         3  Adult          Cinnamon               White  ...
# 9                         3  Adult              Gray            Cinnamon  ...
# 10                        5  Adult              Gray               White  ...
# 12                        1  Adult              Gray            Cinnamon  ...
#
#      Kuks  Quaas  Moans Tail flags Tail twitches  Approaches  Indifferent  \
# 4   False  False  False      False         False       False        False
# 5   False  False  False      False          True       False         True
# 9   False  False  False      False         False       False         True
# 10  False  False  False      False         False       False         True
# 12  False  False  False      False         False       False         True
#
#     Runs from  Other Interactions                                    Lat/Long
# 4       False                 NaN  POINT (-73.9702676472613 40.7762126854894)
# 5       False                 NaN  POINT (-73.9683613516225 40.7725908847499)
# 9       False                 NaN  POINT (-73.9722500196844 40.7742879599026)
# 10      False                 NaN  POINT (-73.9695063535333 40.7823507678183)
# 12      False                 NaN  POINT (-73.9532170504865 40.7919669739962)
#
# [5 rows x 31 columns]

# %%
# Rename the columns
cols_df = pd.DataFrame(s2018_nonull.columns, columns=["name"])

# Define the regex pattern
pattern = '\((.*?)\)' # \( and \) to escape brackets, *.? matches any character (non-newline) zero or more times

new_columns = []
for row in cols_df["name"]:
    # Use underscore and cast to lowercase
    new_columns.append(row.replace(" ", "_").lower())

# Update the columns
s2018_nonull.columns = new_columns

s2018_nonull.head()
# Out:
#             x          y unique_squirrel_id hectare shift      date  \
# 4  -73.970268  40.776213     13E-AM-1017-05     13E    AM  10172018
# 5  -73.968361  40.772591     11H-AM-1010-03     11H    AM  10102018
# 9  -73.972250  40.774288     11D-AM-1010-03     11D    AM  10102018
# 10 -73.969506  40.782351     20B-PM-1013-05     20B    PM  10132018
# 12 -73.953217  40.791967     36I-PM-1007-01     36I    PM  10072018
#
#     hectare_squirrel_number    age primary_fur_color highlight_fur_color  ...  \
# 4                         5  Adult              Gray            Cinnamon  ...
# 5                         3  Adult          Cinnamon               White  ...
# 9                         3  Adult              Gray            Cinnamon  ...
# 10                        5  Adult              Gray               White  ...
# 12                        1  Adult              Gray            Cinnamon  ...
#
#      kuks  quaas  moans tail_flags tail_twitches  approaches  indifferent  \
# 4   False  False  False      False         False       False        False
# 5   False  False  False      False          True       False         True
# 9   False  False  False      False         False       False         True
# 10  False  False  False      False         False       False         True
# 12  False  False  False      False         False       False         True
#
#     runs_from  other_interactions                                    lat/long
# 4       False                 NaN  POINT (-73.9702676472613 40.7762126854894)
# 5       False                 NaN  POINT (-73.9683613516225 40.7725908847499)
# 9       False                 NaN  POINT (-73.9722500196844 40.7742879599026)
# 10      False                 NaN  POINT (-73.9695063535333 40.7823507678183)
# 12      False                 NaN  POINT (-73.9532170504865 40.7919669739962)
#
# [5 rows x 31 columns]

# %%
## Delete unwanted columns but maintain original copy
s2018_drop_columns = s2018_nonull.drop(columns=['hectare', 'shift', 'hectare_squirrel_number', 'age', 'other_interactions'], inplace=False)

# Rename columns to match 2020 dataset
s2018_rename_columns = s2018_drop_columns.rename(columns={"x": "squirrel_longitude", "y": "squirrel_latitude", "highlight_fur_colour": "highlights_in_fur_color", "unique_squirrel_id": "squirrel_id"})

s2018_rename_columns.head()
# Out:
#     squirrel_longitude  squirrel_latitude     squirrel_id      date  \
# 4           -73.970268          40.776213  13E-AM-1017-05  10172018
# 5           -73.968361          40.772591  11H-AM-1010-03  10102018
# 9           -73.972250          40.774288  11D-AM-1010-03  10102018
# 10          -73.969506          40.782351  20B-PM-1013-05  10132018
# 12          -73.953217          40.791967  36I-PM-1007-01  10072018
#
#    primary_fur_color highlight_fur_color  \
# 4               Gray            Cinnamon
# 5           Cinnamon               White
# 9               Gray            Cinnamon
# 10              Gray               White
# 12              Gray            Cinnamon
#
#    combination_of_primary_and_highlight_color color_notes      location  \
# 4                               Gray+Cinnamon         NaN  Above Ground
# 5                              Cinnamon+White         NaN           NaN
# 9                               Gray+Cinnamon         NaN  Above Ground
# 10                                 Gray+White         NaN  Ground Plane
# 12                              Gray+Cinnamon         NaN  Ground Plane
#
#    above_ground_sighter_measurement  ... other_activities   kuks  quaas  \
# 4                               NaN  ...              NaN  False  False
# 5                               NaN  ...              NaN  False  False
# 9                                30  ...         grooming  False  False
# 10                            FALSE  ...              NaN  False  False
# 12                            FALSE  ...              NaN  False  False
#
#     moans  tail_flags  tail_twitches approaches  indifferent  runs_from  \
# 4   False       False          False      False        False      False
# 5   False       False           True      False         True      False
# 9   False       False          False      False         True      False
# 10  False       False          False      False         True      False
# 12  False       False          False      False         True      False
#
#                                       lat/long
# 4   POINT (-73.9702676472613 40.7762126854894)
# 5   POINT (-73.9683613516225 40.7725908847499)
# 9   POINT (-73.9722500196844 40.7742879599026)
# 10  POINT (-73.9695063535333 40.7823507678183)
# 12  POINT (-73.9532170504865 40.7919669739962)
#
# [5 rows x 26 columns]

# %%
# Check the "other activities" column
other_activities = pd.DataFrame(s2018_nonull["other_activities"].value_counts())
other_activities.head(50)
# Out:
#                                                     other_activities
# digging                                                           14
# sitting                                                            9
# playing                                                            8
# burying                                                            6
# nut in mouth                                                       4
# grooming                                                           3
# cleaning                                                           3
# walking                                                            3
# hopping                                                            3
# watching                                                           3
# staring                                                            3
# chasing (#3)                                                       3
# chilling                                                           3
# chillin'                                                           2
# chasing #3                                                         2
# hanging upside down                                                2
# 2/3 were chasing each other                                        2
# chasing (#4)                                                       2
# playing?                                                           2
# chasing #2                                                         2
# watching me                                                        2
# peanuts                                                            2
# eating (red berries)                                               2
# caching                                                            2
# staring at me                                                      2
# burying nut                                                        2
# climbing (tree)                                                    2
# digging deeeep                                                     1
# chasing (#4),digging                                               1
# chasing #15                                                        1
# burying nuts                                                       1
# chasing #4                                                         1
# ambling                                                            1
# checkin' his stashes                                               1
# jumping on fence                                                   1
# hiding a nut                                                       1
# hanging out,watching world                                         1
# scratching self                                                    1
# playing,interacting with #6                                        1
# watching me scratching                                             1
# digging one hole w/ determination                                  1
# dead                                                               1
# hiding                                                             1
# wandering,interacting with tourists                                1
# staying very still to avoid two very curious do...                 1
# scampering w/ squirrel #1                                          1
# collecting nest material                                           1
# foraging?,crossing road                                            1
# chasing squirrel #6                                                1
# crying out                                                         1
