# %%
# Import dependencies
import pandas as pd
from pathlib import Path
import numpy as np

# %%
squirrel_path = Path("squirrel-data.csv")
squirrel_2018 = Path("2018_Central_Park_Squirrel_Census_-_Squirrel_Data.csv")

# %%
squirrel_df = pd.read_csv(squirrel_path, encoding="unicode_escape")
print(squirrel_df.shape)
squirrel_df.head()
# Out:
# (433, 16)
#          Area Name Area ID        Park Name  Park ID Squirrel ID  \
# 0  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-01
# 1  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-02
# 2  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-03
# 3  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-04
# 4  UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-05
#
#   Primary Fur Color Highlights in Fur Color Color Notes      Location  \
# 0              Gray                   White         NaN  Ground Plane
# 1              Gray                   White         NaN  Ground Plane
# 2              Gray                   White         NaN  Ground Plane
# 3              Gray                   White         NaN  Ground Plane
# 4              Gray                Cinnamon         NaN  Ground Plane
#
#   Above Ground (Height in Feet) Specific Location                 Activities  \
# ...

# %%
squirrel_2018 = pd.read_csv(squirrel_2018)
squirrel_2018
# Out:
#               X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0    -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1    -73.968857  40.783783     21B-AM-1019-04     21B    AM  10192018
# 2    -73.974281  40.775534     11B-PM-1014-08     11B    PM  10142018
# 3    -73.959641  40.790313     32E-PM-1017-14     32E    PM  10172018
# 4    -73.970268  40.776213     13E-AM-1017-05     13E    AM  10172018
# ...         ...        ...                ...     ...   ...       ...
# 3018 -73.963943  40.790868     30B-AM-1007-04     30B    AM  10072018
# 3019 -73.970402  40.782560     19A-PM-1013-05     19A    PM  10132018
# 3020 -73.966587  40.783678     22D-PM-1012-07     22D    PM  10122018
# 3021 -73.963994  40.789915     29B-PM-1010-02     29B    PM  10102018
# 3022 -73.975479  40.769640      5E-PM-1012-01     05E    PM  10122018
#
#       Hectare Squirrel Number    Age Primary Fur Color  \
# 0                           3    NaN               NaN
# ...

# %%
squirrel_2018.columns
# Out:
# Index(['X', 'Y', 'Unique Squirrel ID', 'Hectare', 'Shift', 'Date',
#        'Hectare Squirrel Number', 'Age', 'Primary Fur Color',
#        'Highlight Fur Color', 'Combination of Primary and Highlight Color',
#        'Color notes', 'Location', 'Above Ground Sighter Measurement',
#        'Specific Location', 'Running', 'Chasing', 'Climbing', 'Eating',
#        'Foraging', 'Other Activities', 'Kuks', 'Quaas', 'Moans', 'Tail flags',
#        'Tail twitches', 'Approaches', 'Indifferent', 'Runs from',
#        'Other Interactions', 'Lat/Long'],
#       dtype='object')

# %%
squirrel_2018 = squirrel_2018.dropna(
    subset=["Primary Fur Color"],
    how="any")
squirrel_2018
# Out:
#               X          Y Unique Squirrel ID Hectare Shift      Date  \
# 2    -73.974281  40.775534     11B-PM-1014-08     11B    PM  10142018
# 3    -73.959641  40.790313     32E-PM-1017-14     32E    PM  10172018
# 4    -73.970268  40.776213     13E-AM-1017-05     13E    AM  10172018
# 5    -73.968361  40.772591     11H-AM-1010-03     11H    AM  10102018
# 6    -73.954120  40.793181     36H-AM-1010-02     36H    AM  10102018
# ...         ...        ...                ...     ...   ...       ...
# 3018 -73.963943  40.790868     30B-AM-1007-04     30B    AM  10072018
# 3019 -73.970402  40.782560     19A-PM-1013-05     19A    PM  10132018
# 3020 -73.966587  40.783678     22D-PM-1012-07     22D    PM  10122018
# 3021 -73.963994  40.789915     29B-PM-1010-02     29B    PM  10102018
# 3022 -73.975479  40.769640      5E-PM-1012-01     05E    PM  10122018
#
#       Hectare Squirrel Number    Age Primary Fur Color  \
# 2                           8    NaN              Gray
# ...

# %%
squirrel_df.columns
# Out:
# Index(['Area Name', 'Area ID', 'Park Name', 'Park ID', 'Squirrel ID',
#        'Primary Fur Color', 'Highlights in Fur Color', 'Color Notes',
#        'Location', 'Above Ground (Height in Feet)', 'Specific Location',
#        'Activities', 'Interactions with Humans', 'Other Notes or Observations',
#        'Squirrel Latitude (DD.DDDDDD)', 'Squirrel Longitude (-DD.DDDDDD)'],
#       dtype='object')

# %% [markdown]
# # Minimum requirements:
# - lat and long
# - park ID (link to park CSV)
# - squirrel ID (unique?)
# - primary colour
# - DROP NULL for: highlights in fur color

# %%
squirrel_df['Squirrel ID'].nunique()
# Out:
# 433

# %%
no_highlights = squirrel_df.dropna(
    subset=["Highlights in Fur Color", "Activities", "Other Notes or Observations", "Squirrel Latitude (DD.DDDDDD)", "Squirrel Longitude (-DD.DDDDDD)"],
    how="any")
no_highlights
# Out:
#            Area Name Area ID        Park Name  Park ID Squirrel ID  \
# 1    UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-02
# 4    UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-05
# 10   UPPER MANHATTAN       A  Fort Tryon Park        1     A-01-11
# 36   UPPER MANHATTAN       A  Highbridge Park        3     A-03-01
# 37   UPPER MANHATTAN       A  Highbridge Park        3     A-03-02
# ..               ...     ...              ...      ...         ...
# 428         BROOKLYN       D    McCarren Park       22     D-22-40
# 429         BROOKLYN       D    McCarren Park       22     D-22-41
# 430         BROOKLYN       D    McCarren Park       22     D-22-42
# 431         BROOKLYN       D    McCarren Park       22     D-22-43
# 432         BROOKLYN       D    McCarren Park       22     D-22-44
#
#     Primary Fur Color Highlights in Fur Color Color Notes  \
# 1                Gray                   White         NaN
# ...

# %%
# DATE: 01 March 2020 - (3:00PM to 4:38PM)
